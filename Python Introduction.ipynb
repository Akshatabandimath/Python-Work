# %%
Enter_Password =int(input( "Enter your 4 digit password "))

# %%
virat_kohli = 100
virat_kohli
# Out:
# 100

# %%
b = "100"
type(b)
# Out:
# str

# %% [markdown]
# Single Values Assignment

# %% [markdown]
# Multiple Value Assignment

# %%
Name = "victor"

# %%
Salary=2000

# %%
Address = 'Bangalore'

# %%
print(Name)
print(Address)
# Out:
# victor
# Bangalore

# %%
x=y=z=10

# %%
print(y)
# Out:
# 10

# %%
x,y,z =10,15,20

# %%
Class="Python Batch"

# %%
Class.lower()
# Out:
# 'python batch'

# %%
Class.upper()
# Out:
# 'PYTHON BATCH'

# %%
Class='python1'

# %%
Class.title()
# Out:
# 'Python1'

# %%
Class.capitalize()
# Out:
# 'Python1'

# %%
Class.swapcase()
# Out:
# 'PYTHON1'

# %%
a="Amar"
print(a.isalpha)
# Out:
# <built-in method isalpha of str object at 0x78aeaf7af270>

# %%
Class.isalpha()
# Out:
# False

# %%
Class.isalnum()
# Out:
# True

# %%
Class.isnumeric()
# Out:
# False

# %%
Class.startswith("P")
# Out:
# False

# %%
A = "Machine2024"

# %%
A.isalpha()
# Out:
# False

# %%
A.isalnum()
# Out:
# True

# %%
A.isnumeric()
# Out:
# False

# %%
C= "Data Science"
print(C)
# Out:
# Data Science

# %%
C.endswith("d")
# Out:
# False

# %%
C.split()
# Out:
# ['Data', 'Science']

# %%
a ="+91-4558755256"

# %%
#a.split()
a.split("5")
# Out:
# ['+91-4', '', '87', '', '2', '6']

# %%
C.split("a")
# Out:
# ['D', 't', ' Science']

# %%
a="Data Science \n Machine Learning"
print(a)
a.splitlines()
# Out:
# Data Science
#  Machine Learning
# ['Data Science ', ' Machine Learning']

# %%
C= "     banana     "

# %%
C.strip()  # Used for formatting of the data   "   Vyankat   "
# Out:
# 'banana'

# %%
C.lstrip()
# Out:
# 'banana     '

# %%
C.rstrip()
# Out:
# '     banana'

# %%
a="data"    #4 char
a.center(13,"*")
# Out:
# '*****data****'

# %%
print(a.rjust(10,"*"))
a.ljust(10,"*")
# Out:
# ******data
# 'data******'

# %%
a.index("t")  # it will give us the 1st occurance
#data
# Out:
# 2

# %%
#Join is used to merge strings

#E.g:

"d".join("abc")
# Out:
# 'adbdc'

# %%
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-85549cb1de5f> in <cell line: 0>()
# ----> 1 print(d)
#
# NameError: name 'd' is not defined

# %%
"da".join("data sceince")
# Out:
# 'ddaadatdaada dasdacdaedaidandacdae'

# %%
X = "Data Science"
X.count("a")
# Out:
# 2

# %%
# Concatenation of Operators

x =" Data"
y="Science"

# %%
x+y
# Out:
# ' DataScience'

# %%
x+" "+y
# Out:
# ' Data Science'

# %%
x= "DataScience"
#extract Dace

# %%
print(x[0:2]+x[9: ])
# Out:
# Dace

# %%
x = "Machine Learning"

# %%
#Print MALE
#MANE ear
print(x[0:2].upper()+x[5:7].upper()+" " +x[9:12])

x[ :2]+x[8:10]
# Out:
# MANE ear
# 'MaLe'

# %%
x[-2: ]
# Out:
# 'ng'

# %%
(x[0:2]+x[-2: ]).upper()
# Out:
# 'MANG'

# %%
X = ['data',9,'2024.23',3+4j,[10,20,30]]

X[2][4: ]
# Out:
# '.23'

# %%
print(X)
# Out:
# ['data', 9, '2024.23', (3+4j), [10, 20, 30]]

# %%
X[0][0:2]
#print .23
print(X[2][4: ])
# Out:
# .23

# %%
#X[2][4: ]
X[-3][-3: ]
# Out:
# '.23'

# %%
X[-5][-2: ]
# Out:
# 'ta'

# %%
len(X)
topics[0][1][1][0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-78a0203d881d> in <cell line: 0>()
#       1 len(X)
# ----> 2 topics[0][1][1][0:3]
#
# NameError: name 'topics' is not defined

# %%
topics = [
    ['Math', ['Algebra', 'Calculus', 'Geometry']],
    ['Science', ['Physics', 'Chemistry', 'Biology']],
    ['Technology', ['Programming', 'Networking', 'AI']],
    ['History', ['Ancient', 'Medieval', 'Modern']],
    ['Art', ['Painting', 'Sculpture', 'Architecture']]
]

# %%
#print Modern Architecture
topics[3][1][-1]+" "+topics[4][1][2]
# Out:
# 'Modern Architecture'

# %%
#print GEO, BIO, CHEM

topics[0][1][2][0:3].upper()+","+topics[1][1][2][0:3].upper()+","+topics[1][1][1][0:4].upper()
# Out:
# 'GEO,BIO,CHEM'

# %%
topics[0][1][2][0:3].upper() +","+topics[1][1][2][0:3].upper()+ ","+topics[1][1][1][0:3].upper()
# Out:
# 'GEO,BIO,CHE'

# %%
x =1
print(x)
# Out:
# 1

# %%
x=int(input("Enter value of X  "))

# %%
type(x)

# %%
import matplotlib.pyplot as plt

data = {'apples': 20, 'Mangoes': 15, 'Lemon': 30, 'Oranges': 10}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(10, 5))
plt.bar(names, values)
plt.show()

# %%
#Data types in Python:
#1.Immutable Data type
#2.Mutable data type

#Immutable Data Type:
#i. Numeric Data
#ii.String
#iii.tuple

#Mutable Data Type:
#i.List
#ii. Dictionary

#i.Numeric Data Type:
#1.Integer  #2.Float   3.Complex

#1.Integer:this value is represented by int class.
#interger contains +v-0--ve i.e.whole numbers
#in python there is no limit how long an interger value be

X= 15
type(x)
y=int(input("Assign value to Y"))

#2.Float: This value is represented by decimal point.

# %%
x = -150005464646198465184646198494564
print(x)
type(x)
# Out:
# -150005464646198465184646198494564
# int

# %%
w=66.5
print(w)
type(w)
# Out:
# 66.5
# float

# %%
w = float(input("Give a Decimal Values: "))

# %%
c=66.5

# %%
#Complex : n + ij

b =5+4j

type(b)
